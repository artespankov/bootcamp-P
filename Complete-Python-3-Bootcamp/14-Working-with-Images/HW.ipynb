# %%
from PIL import Image

# %%
words_img = Image.open("word_matrix.png")

# %%
mask = Image.open('mask.png')

# %%
mask.resize((1015, 559))
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x7FE45441B650>

# %%
mask = mask.resize((1015, 559))
mask.putalpha(100)
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x7FE4538856D0>

# %%
words_img
#words_img.alpha_composite(im=mask)
#words_img

words_img.paste(im=mask, box=(0,0), mask=mask)
words_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x7FE4538ADD10>
